# %%
from transformers import AutoTokenizer, AutoModelForCausalLM

model_name = "BramVanroy/fietje-2"

# Load tokenizer and model
tokenizer = AutoTokenizer.from_pretrained(model_name)
print(tokenizer.vocab_size)
# model = AutoModelForCausalLM.from_pretrained(model_name)

# # Input text (Dutch works best)
# prompt = "Nederland is een klein land maar"

# inputs = tokenizer(prompt, return_tensors="pt")

# # Generate text
# outputs = model.generate(
#     **inputs,
#     max_new_tokens=200,
#     do_sample=True,
#     temperature=0.8,
#     top_p=0.95
# )

# # Decode output
# generated_text = tokenizer.decode(outputs[0], skip_special_tokens=True)
# print(generated_text)
# Out:
# 50257

# %%
tokenizer = AutoTokenizer.from_pretrained("GroNLP/bert-base-dutch-cased")
print(tokenizer.vocab_size)
# Out:
# 30073

# %%
tokenizer = AutoTokenizer.from_pretrained("RichardErkhov/yhavinga_-_Boreas-7B-chat-8bits")
print(tokenizer.vocab_size)
# Out:
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# tokenizer.model:   0%|          | 0.00/493k [00:00<?, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/624 [00:00<?, ?B/s]
# 32000

# %%
tokenizer = AutoTokenizer.from_pretrained("GroNLP/gpt2-small-dutch")
print(tokenizer.vocab_size)
# Out:
# tokenizer_config.json:   0%|          | 0.00/108 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/957 [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/63.0 [00:00<?, ?B/s]
# 40000
